# %%
#print the result of 25+75
print("The sum of 25 and 75 ")
print("Result is =",25+75)
# Out:
# The sum of 25 and 75
# Result is = 100

# %%
#print the result of 50-18
print("The subtraction of 50 and 18")
print("Result =",50-18)
# Out:
# The subtraction of 50 and 18
# Result = 32

# %%
#create two variables a=15 and b=15. print sum
a=15
b=5
print("The sum of a and b :")
print("a =", a, "b =", b)
print( "Result of:",a+b)
# Out:
# The sum of a and b :
# a = 15 b = 5
# Result of: 20

# %%
#create two variables x=20 and y=4. Print their division.
x=20
y=4
print("The division of x and y: ")
print("x =",x ,"y =",y)
print("Result of Division :",x/y)
# Out:
# The division of x and y:
# x = 20 y = 4
# Result of Division : 5.0

# %%
#create  variables length =10 and width=6. calculate and print the perimeter of a rectangle
length=10
width=6
perimeter=2*(length+width)
print("length =", length , "width =", width)
print("Result is :", perimeter)
# Out:
# length = 10 width = 6
# Result is : 32

# %%
#create variable price=250 and quantity=3.Print total
price=250
quantity=3
print("price =",price, "quantity =",quantity)
total_cost=price*quantity
print("Total cost of :",total_cost)
# Out:
# price = 250 quantity = 3
# Total cost of : 750

# %%
#calculate and print the square of 12. add comment explaining the code 
num=12
square=num*num
print("The square of 12 is :",square)
# Out:
# The square of 12 is : 144

# %%
#write  a multiple line comment (Hello; this is  a multi line comment ;Bye and print Hello
"""Hello
   This is a multi line comment
   Bye"""
print("Hello")
# Out:
# Hello

# %%
#print your name , surname ,hobby,weight,no.of siblings in a form of paragraph.
name= "Rahul"
surname="Patidar"
hobby="playing cricket "
weight=65.5
siblings=2
print(f'My name is {name} {surname}.I enjoy {hobby} and. My weigth is {weight} kg and  i have   sibling  {siblings}')
# Out:
# My name is Rahul Patidar.I enjoy playing cricket  and. My weigth is 65.5 kg and  i have   sibling  2

# %%
#what will be the output of (2+3*4) and ((2+3)*4)
print("The output of (2+3*4) is :",2+3*4)
print("The output of((2+3)*4) is :",(2+3)*4)
# Out:
# The output of (2+3*4) is : 14
# The output of((2+3)*4) is : 20
