# %%
#1. Write a program to take a user's name as input and print a greeting message.
name=input("Enter your name:")
print("Hello!",name)
# Out:
# Enter your name: Rohit
# Hello! Rohit

# %%
#2 Take two integers as input from the user and print their sum.
a=int(input("Enter a first number:"))
b=int(input("Enter a second number:"))
print("The sum of is :",a+b)
# Out:
# Enter a first number: 10
# Enter a second number: 20
# The sum of is : 30

# %%
#3 Take a float input from the user and print its square.
num=float(input("Enter a number:"))
square=num*num
print("square of:",square)
# Out:
# Enter a number: 4
# square of: 16.0

# %%
#4Take three numbers as input and print the largest among them.
num1=int(input("Enter a first number:"))
num2=int(input("Enter a second number:"))
num3=int(input("Enter a third number:"))
largest=max(num1,num2,num3)
print("largest numbr is :",largest)
# Out:
# Enter a first number: 10
# Enter a second number: 20
# Enter a third number: 15
# largest numbr is : 20

# %%
#5 Take a string input and print its length.
a=input("Enter your name:")
print(a,"\nThe length of string is:",len(a))
# Out:
# Enter your name: Rahul
# Rahul
# The length of string is: 5

# %%
#6.Take input for age and check if the person is eligible to vote (>=18).

age=int(input("Enter your age: "))
print("you are eligible to for voting:",age>=18)
# Out:
# Enter your age:  19
# you are eligible to for voting: True

# %%
# 7. Take a number as input and check whether it is even or odd.
num=int(input("Enter a number:"))
print(num % 2==0)

# %%
#8. Take a character input and check whether it is a vowel or consonant.
vowel=input("Enter character:")
print(vowel in "AEIOUaeiou")
# Out:
# Enter character: aeiou
# True

# %%
#9. Take two numbers and print their quotient and remainder.
num1=int(input("Enter a first number:"))
num2=int(input("Enter a second number:"))

q=num1//num2
r=num1%num2

print("quotient: {} \nremainder: {}".format(q,r))
# Out:
# Enter a first number: 7
# Enter a second number: 3
# quotient: 2
# remainder: 1

# %%
#10. Take temperature in Celsius as input and convert it to Fahrenheit.
C=float(input("Enter a celsius value:"))
F=(C * 9/5)+32
print("Celsius to Fahrenheit:",F)

Fah=float(input("Enter a Fahrenheit value:"))
cels=(Fah-32)*5/9
print("Fahrenheit to celsius is:",cels)
# Out:
# Enter a celsius value: 14
# Celsius to Fahrenheit: 57.2
# Enter a Fahrenheit value: 57.2
# Fahrenheit to celsius is: 14.000000000000002

# %%
#11.Take a mathematical expression as input (e.g., "2+3*5") and evaluate it using eval().

exp=input("Enter  expression:")
result=eval(exp)
print("The Result is :",result)
# Out:
# Enter  expression: 2+3*5
# The Result is : 17

# %%
#12. Take two numbers as input in a single line separated by space and evaluate their sum using eval().
a, b = eval(input("Enter two numbers: "))

print("sum is:",a + b)
# Out:
# Enter two numbers:  3,2
# sum is: 5

# %%
#13. Take a list input from the user (e.g., "[1,2,3,4]") and find the sum of elements using eval().
lst = eval(input("Enter list: "))

print("Result is:",sum(lst))
# Out:
# Enter list:  [1,2,3,4]
# result is: 10

# %%
#14. Take a tuple input and print the maximum element using eval().
tupl=eval(input("Enter a tuple:"))
print("Result is",max(tupl))
# Out:
# Enter a tuple: (1,2,3,17)
# Result is 17

# %%
#15. Take a dictionary input and print all keys using eval().
d = eval(input("Enter dictionary: "))

print(d.keys())
# Out:
# Enter dictionary:  {"a":1,"b":2,"c":3}
# dict_keys(['a', 'b', 'c'])

# %%
#16. Take multiple integers in one line using eval() and store them into variables.
a,b,c=eval(input("Enter values :"))
print("Result is:",a,b,c)
# Out:
# Enter values : 10,20,30
# 10 20 30

# %%
#17. Take a boolean expression (e.g., "5>3") and evaluate its result using eval().
exp = eval(input("Enter expression:")) 
print("The Result is:",eval(exp))
# Out:
# Enter expression: "5>3"
# The Result is: True

# %%
#18.Take a list input and count how many elements are greater than 10.
lst = eval(input("Enter list: "))

count = 0

for i in lst:
    if i > 10:
        count = count + 1

print("The result is ",count)
# Out:
# Enter list:  [5,12,13,7,3,11]
# 3

# %%
#18------------------------Take a list input and count how many elements are greater than 10.

lst=eval(input("enter list:"))
count=sum(1 for i in lst if i>10)
print(count)
# Out:
# enter list: [5,2,22,12]
# 2

# %%
#19. Take a string expression that includes arithmetic operations and evaluate it.
exp = input("Enter expression: ")
result=eval(exp)
print("The result is :",result)
# Out:
# Enter expression:  5+3
# The result is : 8

# %%
#20. Take nested list input using eval() and flatten it.
lst=eval(input("Enter a nested list:"))
flatten=lst[0]+lst[1]
print(flatten)
# Out:
# Enter a nested list: [[1,2],[3,4]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #20. Take nested list input using eval() and flatten it.
#       2 lst=eval(input("Enter a nested list:"))
# ----> 3 flatten=list[0]+list[1]
#       4 print(flatten)
#
# TypeError: unsupported operand type(s) for +: 'types.GenericAlias' and 'types.GenericAlias'

# %%
#21. Write a program to demonstrate all arithmetic operators (+, -, *, /, %, //, **).
a=int(input("Enter a  first number:"))
b=int(input("Enter a second number"))
print("Addition is :",a+b)
print("Subtrac. is :",a-b)
print("Multiply is :",a*b)
print("Division is :",a/b)
print("Modulos is :",a%b)
print("Floor divison is :",a//b)
print("power is :",a**b)
# Out:
# Enter a  first number: 3
# Enter a second number 2
# Addition is : 5
# Subtrac. is : 1
# Multiply is : 6
# Division is : 1.5
# Modulo is : 1
# Floor divison is : 1
# power is : 9

# %%
#22. Take two numbers and compare them using relational operators (>, <, ==, !=).
a = int(input("Enter a first number:"))
b = int(input("Enter a second number:"))

print(a > b)
print(a < b)
print(a == b)
print(a != b)
# Out:
# Enter a first number: 20
# Enter a second number: 10
# True
# False
# False
# True

# %%
#23. Check whether a number lies between 10 and 50 using logical operators.

n = int(input())

print(n > 10 and n > 50)
print(n<10 or n>50)
# Out:
#  70
# True
# True

# %%
#24. Take two boolean inputs and demonstrate AND, OR, NOT operations.
a = eval(input())
b = eval(input())

print(a and b)
print(a or b)
print(not a)
# Out:
#  1
#  0
# 0
# 1
# False

# %%
#25. Write a program to check if a number is divisible by both 3 and 5.
n=int(input("Enter a value:"))
print("The result is :",n % 3==0 and n%5==0)
# Out:
# Enter a value: 15
# The result is : True

# %%
#26. Use assignment operators (+=, -=, *=) to update a variable.
x =int(input("Enter a value:"))

x += 5
print("addition x=x+5 is:",x)
x -= 2
print("after subtract x=x-2 is:",x)
x *= 3
print("after multiply x=x*3 is:",x)
# Out:
# Enter a value: 10
# addition x=x+5 is: 15
# after subtract x=x-2 is: 13
# after multiply x=x*3 is: 39

# %%
#27. Check whether a number is not equal to zero using comparison operators.
num=int(input("enter a numbert"))
print("The result is :" ,num != 0)
# Out:
# enter a numbert 0
# The result is : False

# %%
#28. Use bitwise operators (&, |, ^) on two integers and display results.
a = int(input())
b = int(input())

print("AND:",a & b)
print("OR:",a | b)
print(":",a ^ b)
# Out:
#  0
#  1
# AND: 0
# OR: 1
# : 1

# %%
#29. Take two numbers and perform floor division and exponentiation.
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
print("The floor division is:",num1//num2)
print("The exponentiation is:",num1**num2)
# Out:
# Enter first number: 3
# Enter second number: 2
# The floor division is: 1
# The exponentiation is: 9

# %%
#30. Check operator precedence by evaluating a complex expression like: 2 + 3 * 4 ** 2 // 2
exp=input("enter expression:")  
b=eval(exp)
print("The result is:",b)

'''first **,second *,third //, last is +.'''
# Out:
# enter expression: 2 + 3 * 4 ** 2 // 2
# The result is: 26

# %%
#31. Write a program to swap two numbers using operators without using a third variable.
a=int(input("Enter first number:"))
b=int(input("Enter sec. number:"))
a,b=b,a
print("The result is :",a,b)
# Out:
# Enter first number: 10
# Enter sec. number: 20
# The result is : 20 10

# %%
#32. Check if a number is positive, negative, or zero using conditional operators.
num=int(input("Enter a number:"))
print("the result is:",num>0,num<0,num==0)
# Out:
# Enter a number: 0
# the result is: False False True

# %%
#33. Take three numbers and use logical operators to find the greatest.
a=int(input("Enter first number:"))
b=int(input("Enter sec. number:"))
c=int(input("Enter third number:"))
print("The gratest number is:",max(a,b,c))
# Out:
# Enter first number: 10
# Enter sec. number: 20
# Enter third number: 15
# The gratest number is: 20

# %%
#34. Use identity operators (is, is not) to compare two variables.
a=list(input("Enter value:"))
b=list(input("Enter value:"))
print("a is b:",a is b)
print("a is not b:",a is not b)
# Out:
# Enter value: [1,2]
# Enter value: [1,2]
# a is b: False
# a is not b: True

# %%
#35. Use membership operators (in, not in) to check if an element exists in a list.
a=int(input("Enter value:"))
b=int(input("Enter value:"))
lst = [1,2,3,4]
print(a in lst)
print(b in lst)
print(a not in lst)
print(b not in lst)
# Out:
# Enter value: 3
# Enter value: 4
# True
# True
# False
# False

# %%
#36. Combine arithmetic and logical operators in a single expression.
a=int(input())
b=int(input())

print( "The result is:",a*b>10 and a*b<50)
print("The result is:",a*b>10 or a*b<50)
# Out:
#  3
#  4
# The result is: True
# The result is: True

# %%
#37. Write a program to calculate simple interest using operators. using ----.I = P × R × T
P= float(input("Enter value:"))
R= float(input("Enter value:"))
T= float(input("Enter value:"))
I=P*R*T
print("The interest is:",I)
# Out:
# Enter value: 10000
# Enter value: 0.06
# Enter value: 6
# The interest is: 3600.0

# %%
#38. Write a program to calculate area of a circle using operators.  ---- area=3.14*r*r
r=float(input("Enter value:"))
area=3.14*r*r
print("The area of circle is:",area)
# Out:
# Enter value: 4.2
# The area of circle is: 55.3896

# %%
#39. Write a program to calculate compound interest using operators. ci = p * (1 + r/100) ** t
p = float(input( "Enter value:"))
r = float(input("Enter value:"))
t = float(input("Enter value:"))
ci=p*(1+r/100)**t
print("compound interest is:",ci)
# Out:
# Enter value: 20
# Enter value: 44
# Enter value: 2
# compound interest is: 41.471999999999994

# %%
#40. Evaluate a complex expression involving multiple operators and explain the result.
exp = eval(input("Enter expression: "))
print("The result is:", exp)
# Out:
# Enter expression:  (10 + 5 * 2) / (3 + 2)
# The result is: 4.0
