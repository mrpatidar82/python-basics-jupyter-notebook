# %%
#1. random
import random
print(random.random())  #print only decimal no. 0 or 1 ke bich me sirf
# Out:
# 0.005679505077471725

# %%
# randint
import random
from random import randint
print(random.randint(1,10))  #random number generate  krega 1,10 ke bich me or int value he dega
# Out:
# 1

# %%
# randrange
import random
from random import randrange
print(random.randrange(1,10)) # 1-9 tak ki range but 10 included nhi
# Out:
# 5

# %%
#Choice
import random
from random import choice
num=(1,2,3,4,5)  # tuple ,list , koi b series in variable
print(random.choice(num)) # series me se koi b random number de dega
# Out:
# 2

# %%
#choices
import random
from random import choices
lst = [1,2,3]
print(random.choices(lst, k=2))
tup=(1,2,3,4,5)
print(random.choices(tup, k=3))
# Out:
# [1, 1]
# [1, 2, 5]

# %%
#6. shuffle
import random
from random import shuffle
lst = [1,2,3,4]
random.shuffle(lst)
print(lst) # list ko shuffle karta he har bar list ka order change ho jata he
# Out:
# [1, 4, 3, 2]

# %%
#7.sample
import random
from random import sample

lst = [1,2,3,4]
print(random.sample(lst, 2))

name="rahul"
print(random.sample(name,3))  # random characters de dega string me se
# Out:
# [3, 1]
# ['l', 'u', 'a']

# %%
#uniform
import random
from random import uniform 
num,num2=1,10
print(random.uniform(num,num2))   # do integer value ke bich me float(decimal) number generate karta he random or value 1,or 10 b de skta he
# Out:
# 1.569959243091728

# %% [markdown]
# # MATH
#
# 1. ceil
# 2. floor
# 3. sqrt
# 4. pow
# 5. factorial
# 6. fabs
# 7. gcd
# 8. log
# 9. log10
# 10. exp

# %%
#1. ceil
import math
from math import ceil
num=5.5
print(math.ceil(num)) #ceil() ka matlab hota hai number ko upar wale nearest integer tak round karna  value float me he honi chahiye
# Out:
# 6

# %%
#2. floor -----floor() ka matlab hota hai number ko niche wale nearest integer tak round karna 7.9 ki lowest or nearest value batayega
import math
from math import floor
num=7.9
print(math.floor(num))
# Out:
# 7

# %%
#3. sqrt
import math
from math import sqrt
num=4
print(math.sqrt(num))  #  sqr. root nikalta he number ka
# Out:
# 2.0

# %%
#4.pow
import math
from math import pow
num=2
print(math.pow(num,2)) #Power (exponent) nikalta hai
# Out:
# 4.0

# %%
#5.factorial
import math
from math import factorial
fact=4
print(math.factorial(fact))  #number ka factorial nikalega only int.
# Out:
# 24

# %%
#6.fabs 
import math
from math import fabs
num=-10
print(math.fabs(num))  #Value (hamesha positive)
# Out:
# 10.0

# %%
#7.gcd gratest common division
import math
from math import gcd
num1,num2=10,15
print(math.gcd(num1,num2))
# Out:
# 5

# %%
#8. log-----------------Ye logarithm base e (≈ 2.718) nikalta hai
import math
from math import log
num=10
print(math.log(num))    #e ko kis power pe uthaye ki 10 mile”
# Out:
# 2.302585092994046

# %%
#9.log10 --------------------Ye base 10 ka logarithm nikalta hai
import math
from math import log10
num=100
print(math.log10(num))    #“10 ko kis power pe uthaye ki num mile”
# Out:
# 2.0

# %%
#10.exp ------------------Ye e^x (e power x) nikalta hai
import math
from math import exp
num=2
power=math.exp(num)
print(power)
# Out:
# 7.38905609893065

# %% [markdown]
# # ### **Datetime Module**
#
# 1. datetime
# 2. date
# 3. time
# 4. timedelta
# 5. now
# 6. today
# 7. strftime
# 8. strptime
# 9. timestamp
# 10. fromtimestamp

# %%
#1.date time
import datetime
from datetime import datetime
d=datetime.now()
print(d)  # current date + time deta hai
# Out:
# 2026-03-26 13:52:54.389415

# %%
#2.date
from datetime import date
date=date.today()
print(date)#current date dega
# Out:
# 2026-03-26

# %%
#3.time
from datetime import time
now=datetime.now()
t=now.time()
print(t)#sirf current time nikalta he
# Out:
# 13:53:51.928580

# %%
#4.timedelta--------------timedelta date ko add ya subtract karne ke kaam aata hai
from datetime import timedelta
print(timedelta(days=6))

from datetime import datetime, timedelta
today=datetime.now()
ft=today+timedelta(days=5) #aaj se 5 din baad ki date
print(ft)

past=today-timedelta(days=4)
print(past)
# Out:
# 6 days, 0:00:00
# 2026-03-31 13:56:01.169707
# 2026-03-22 13:56:01.169707

# %%
#5.now
from datetime import datetime
dt=datetime.now()
print(dt)  #current date & time
# Out:
# 2026-03-26 13:57:30.795624

# %%
#6 today------------current date  deta he 
from datetime import date
date=datetime.today()
print(date)
# Out:
# 2026-03-26 14:00:31.621480

# %%
#7.strftime------------------Date ko string format me convert karta hai
from datetime import datetime
now = datetime.now()
print(now.strftime("%d-%m-%Y"))
print(now.strftime("%d-%B-%Y %H:%M:%S"))
# Out:
# 26-03-2026
# 26-March-2026 11:06:54

# %%
#8.strptime---------string ko date me convert kar diya
from datetime import datetime
d = datetime.strptime("26-03-2026", "%d-%m-%Y")
print(d)
# Out:
# 2026-03-26 00:00:00

# %%
#9.timestamp------------Date/time ko seconds (Unix format) me convert karta hai
from datetime import datetime
now=datetime.now()
sec=now.timestamp()
print(sec)
# Out:
# 1774513712.154998

# %%
#10.fromtimestamp
from datetime import datetime
in_dt=datetime.fromtimestamp(8000000)
print(in_dt)
# Out:
# 1970-04-03 19:43:20

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import datetime
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  'UTC',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...
